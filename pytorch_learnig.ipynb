# %% [markdown]
# # Pytorch
#
# ### Czym jest PyTorch?
# PyTorch to platforma uczenia maszynowego i głębokiego uczenia o otwartym kodzie źródłowym z zaimplementowaną akceleracją GPU.
#
# ### Do czego można wykorzystać PyTorch?
# PyTorch umożliwia manipulowanie i przetwarzanie danych oraz pisanie algorytmów uczenia maszynowego przy użyciu kodu Python.
#
# ### Kto używa PyTorch?
# Wiele największych na świecie firm technologicznych, takich jak Meta (Facebook), Tesla i Microsoft, a także firmy zajmujące się badaniami nad sztuczną inteligencją, takie jak OpenAI, używają PyTorch do prowadzenia badań i wprowadzania uczenia maszynowego do swoich produktów.

# %% [markdown]
# # Najważniejsze ogniwo czyli Tensor

# %%
# ! pip install torch

# %%
tensor = torch.tensor(
    [[[1.0, 2.0], [3.0, 4.0], [2.0, 6.0]], [[5.0, 6.0], [7.0, 8.0], [3.0, 4.0]]]
)
print(tensor)
# Out:
# tensor([[[1., 2.],
#          [3., 4.],
#          [2., 6.]],
#
#         [[5., 6.],
#          [7., 8.],
#          [3., 4.]]])

# %%
tensor.size()
# Out:
# torch.Size([2, 3, 2])

# %% [markdown]
# <img src="https://camo.githubusercontent." alt="opis" style="width: 80%;"/>

# %%
import numpy as np
import time

# Rozmiar tensorów/tablic
size = (1000, 1000)

# Tworzenie tensorów i tablic
tensor_a = torch.rand(size)
tensor_b = torch.rand(size)


# Mierzenie czasu dla PyTorch
start_time = time.time()
for _ in range(1000):
    tensor_result = torch.matmul(tensor_a, tensor_b)
torch_time = time.time() - start_time


print(f"PyTorch: {torch_time:.5f} s")
# Out:
# PyTorch: 1.38374 s

# %%
array_a = np.random.rand(*size)
array_b = np.random.rand(*size)

start_time = time.time()
for _ in range(1000):
    array_result = np.dot(array_a, array_b)
numpy_time = time.time() - start_time

print(f"NumPy: {numpy_time:.5f} s")
# Out:
# NumPy: 5.30298 s

# %%
#chck divice and coment
if torch.cuda.is_available():
    device = torch.device("cuda")
    print("GPU aktywne")
else:
    device = torch.device("cpu")
    print("GPU nieaktywne")
# Out:
# GPU aktywne

# %%
tensor_a = torch.rand(size).to(device)
tensor_b = torch.rand(size).to(device)


# Mierzenie czasu dla PyTorch
start_time = time.time()
for _ in range(1000):
    tensor_result = torch.matmul(tensor_a, tensor_b).to(device)
torch_time = time.time() - start_time

print(f"PyTorch on GPU: {torch_time:.5f} s")
# Out:
# PyTorch on GPU: 0.12140 s

# %% [markdown]
# # x10 więcej obliczeń

# %%
# Mierzenie czasu dla PyTorch
start_time = time.time()
for _ in range(10000):
    tensor_result = torch.matmul(tensor_a, tensor_b).to(device)
torch_time = time.time() - start_time

print(f"PyTorch on GPU: {torch_time:.5f} s")
# Out:
# PyTorch on GPU: 1.75410 s

# %% [markdown]
# # Tworzenie i ucznie pierwszego modelu

# %% [markdown]
# Aby lepiej zrozumieć na czym polega projektowanie sieci neuronowych polecam wypróbować playground od tensorflow. Zadanie osoągnąć jak najniższy `Test loss`
# https://playground.tensorflow.org

# %% [markdown]
# ![Screenshot from 2024-03-25 21-43-16.png](<attachment:Screenshot from 2024-03-25 21-43-16.png>)

# %% [markdown]
# ## Przygotowanie danych

# %%
from sklearn.datasets import make_circles


# Make 1000 samples 
n_samples = 1000

# Create circles
X, y = make_circles(n_samples,
                    noise=0.03, # a little bit of noise to the dots
                    random_state=42) # keep random state so we get the same values

# %%
# Make DataFrame of circle data
import pandas as pd
circles = pd.DataFrame({"X1": X[:, 0],
    "X2": X[:, 1],
    "label": y
})
circles.head(10)
# Out:
#          X1        X2  label
# 0  0.754246  0.231481      1
# 1 -0.756159  0.153259      1
# 2 -0.815392  0.173282      1
# 3 -0.393731  0.692883      1
# 4  0.442208 -0.896723      0
# 5 -0.479646  0.676435      1
# 6 -0.013648  0.803349      1
# 7  0.771513  0.147760      1
# 8 -0.169322 -0.793456      1
# 9 -0.121486  1.021509      0

# %%
# Visualize with a plot
import matplotlib.pyplot as plt
plt.scatter(x=X[:, 0], 
            y=X[:, 1], 
            c=y, 
            cmap=plt.cm.RdYlBu);

# %%
# View the first example of features and labels
X_sample = X[0]
y_sample = y[0]
print(f"Values for one sample of X: {X_sample} and the same for y: {y_sample}")
print(f"Shapes for one sample of X: {X_sample.shape} and the same for y: {y_sample.shape}")
# Out:
# Values for one sample of X: [0.75424625 0.23148074] and the same for y: 1
# Shapes for one sample of X: (2,) and the same for y: ()

# %%
# Turn data into tensors
# Otherwise this causes issues with computations later on
import torch
X = torch.from_numpy(X).type(torch.float)
y = torch.from_numpy(y).type(torch.float)

# View the first five samples
X[:5], y[:5]
# Out:
# (tensor([[ 0.7542,  0.2315],
#          [-0.7562,  0.1533],
#          [-0.8154,  0.1733],
#          [-0.3937,  0.6929],
#          [ 0.4422, -0.8967]]),
#  tensor([1., 1., 1., 1., 0.]))

# %%
# Split data into train and test sets
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    test_size=0.2, # 20% test, 80% train
                                                    random_state=42) # make the random split reproducible

len(X_train), len(X_test), len(y_train), len(y_test)
# Out:
# (800, 200, 800, 200)

# %% [markdown]
# # Projektowanie archtektury modelu

# %%
# 1. Construct a model class that subclasses nn.Module
class CircleModelV0(nn.Module):
    def __init__(self):
        super().__init__()
        # 2. Create 2 nn.Linear layers capable of handling X and y input and output shapes
        self.layer_1 = nn.Linear(in_features=2, out_features=5) # takes in 2 features (X), produces 5 features
        self.layer_2 = nn.Linear(in_features=5, out_features=1) # takes in 5 features, produces 1 feature (y)
    
    # 3. Define a forward method containing the forward pass computation
    def forward(self, x):
        # Return the output of layer_2, a single feature, the same shape as y
        return self.layer_2(self.layer_1(x)) # computation goes through layer_1 first then the output of layer_1 goes through layer_2

# 4. Create an instance of the model and send it to target device
model_0 = CircleModelV0().to(device)
model_0
# Out:
# CircleModelV0(
#   (layer_1): Linear(in_features=2, out_features=5, bias=True)
#   (layer_2): Linear(in_features=5, out_features=1, bias=True)
# )

# %%
# Create a loss function
# loss_fn = nn.BCELoss() # BCELoss = no sigmoid built-in
loss_fn = nn.BCEWithLogitsLoss() # BCEWithLogitsLoss = sigmoid built-in

# Create an optimizer
optimizer = torch.optim.SGD(params=model_0.parameters(), 
                            lr=0.1)

# %%
# Calculate accuracy (a classification metric)
def accuracy_fn(y_true, y_pred):
    correct = torch.eq(y_true, y_pred).sum().item() # torch.eq() calculates where two tensors are equal
    acc = (correct / len(y_pred)) * 100 
    return acc

# %% [markdown]
# # Uczenie modelu

# %%
torch.manual_seed(42)

# Set the number of epochs
epochs = 100

# Put data to target device
X_train, y_train = X_train.to(device), y_train.to(device)
X_test, y_test = X_test.to(device), y_test.to(device)

# Build training and evaluation loop
for epoch in range(epochs):
    ### Training
    model_0.train()

    # 1. Forward pass (model outputs raw logits)
    y_logits = model_0(X_train).squeeze() # squeeze to remove extra `1` dimensions, this won't work unless model and data are on same device 
    y_pred = torch.round(torch.sigmoid(y_logits)) # turn logits -> pred probs -> pred labls
  
    # 2. Calculate loss/accuracy
    # loss = loss_fn(torch.sigmoid(y_logits), # Using nn.BCELoss you need torch.sigmoid()
    #                y_train) 
    loss = loss_fn(y_logits, # Using nn.BCEWithLogitsLoss works with raw logits
                   y_train) 
    acc = accuracy_fn(y_true=y_train, 
                      y_pred=y_pred) 

    # 3. Optimizer zero grad
    optimizer.zero_grad()

    # 4. Loss backwards
    loss.backward()

    # 5. Optimizer step
    optimizer.step()

    ### Testing
    model_0.eval()
    with torch.inference_mode():
        # 1. Forward pass
        test_logits = model_0(X_test).squeeze() 
        test_pred = torch.round(torch.sigmoid(test_logits))
        # 2. Caculate loss/accuracy
        test_loss = loss_fn(test_logits,
                            y_test)
        test_acc = accuracy_fn(y_true=y_test,
                               y_pred=test_pred)

    # Print out what's happening every 10 epochs
    if epoch % 10 == 0:
        print(f"Epoch: {epoch} | Loss: {loss:.5f}, Accuracy: {acc:.2f}% | Test loss: {test_loss:.5f}, Test acc: {test_acc:.2f}%")
# Out:
# Epoch: 0 | Loss: 0.71529, Accuracy: 50.00% | Test loss: 0.70585, Test acc: 50.00%
# Epoch: 10 | Loss: 0.70381, Accuracy: 55.88% | Test loss: 0.69603, Test acc: 58.50%
# Epoch: 20 | Loss: 0.69939, Accuracy: 53.62% | Test loss: 0.69260, Test acc: 53.50%
# Epoch: 30 | Loss: 0.69745, Accuracy: 51.38% | Test loss: 0.69140, Test acc: 53.00%
# Epoch: 40 | Loss: 0.69643, Accuracy: 51.12% | Test loss: 0.69100, Test acc: 52.00%
# Epoch: 50 | Loss: 0.69578, Accuracy: 50.62% | Test loss: 0.69091, Test acc: 53.50%
# Epoch: 60 | Loss: 0.69532, Accuracy: 49.88% | Test loss: 0.69095, Test acc: 53.00%
# Epoch: 70 | Loss: 0.69495, Accuracy: 49.75% | Test loss: 0.69104, Test acc: 53.50%
# Epoch: 80 | Loss: 0.69466, Accuracy: 50.12% | Test loss: 0.69117, Test acc: 53.50%
# Epoch: 90 | Loss: 0.69441, Accuracy: 50.00% | Test loss: 0.69131, Test acc: 53.50%

# %%
# 1. Construct a model class that subclasses nn.Module
class CircleModelV1(nn.Module):
    def __init__(self):
        super().__init__()
     
        self.layer_1 = nn.Linear(in_features=2, out_features=10)
        self.layer_2 = nn.Linear(in_features=10, out_features=10) # extra layer
        self.layer_3 = nn.Linear(in_features=10, out_features=1)
        self.relu = nn.ReLU()
    
    # 3. Define a forward method containing the forward pass computation
    def forward(self, x):
        x = self.layer_1(self.relu(x))
        x = self.layer_2(self.relu(x))
        x = self.layer_3(self.relu(x))
        return x

# 4. Create an instance of the model and send it to target device
model_1 = CircleModelV1().to(device)
model_1
# Out:
# CircleModelV1(
#   (layer_1): Linear(in_features=2, out_features=10, bias=True)
#   (layer_2): Linear(in_features=10, out_features=10, bias=True)
#   (layer_3): Linear(in_features=10, out_features=1, bias=True)
#   (relu): ReLU()
# )

# %%
# Setup loss and optimizer 
loss_fn = nn.BCEWithLogitsLoss()
optimizer = torch.optim.SGD(model_1.parameters(), lr=0.1)

# %%
# Fit the model
torch.manual_seed(42)
epochs = 10000

# Put all data on target device
X_train, y_train = X_train.to(device), y_train.to(device)
X_test, y_test = X_test.to(device), y_test.to(device)

for epoch in range(epochs):
    # 1. Forward pass
    y_logits = model_1(X_train).squeeze()
    y_pred = torch.round(torch.sigmoid(y_logits)) # logits -> prediction probabilities -> prediction labels
    
    # 2. Calculate loss and accuracy
    loss = loss_fn(y_logits, y_train) # BCEWithLogitsLoss calculates loss using logits
    acc = accuracy_fn(y_true=y_train, 
                      y_pred=y_pred)
    
    # 3. Optimizer zero grad
    optimizer.zero_grad()

    # 4. Loss backward
    loss.backward()

    # 5. Optimizer step
    optimizer.step()

    ### Testing
    model_1.eval()
    with torch.inference_mode():
      # 1. Forward pass
      test_logits = model_1(X_test).squeeze()
      test_pred = torch.round(torch.sigmoid(test_logits)) # logits -> prediction probabilities -> prediction labels
      # 2. Calcuate loss and accuracy
      test_loss = loss_fn(test_logits, y_test)
      test_acc = accuracy_fn(y_true=y_test,
                             y_pred=test_pred)

    # Print out what's happening
    if epoch % 100 == 0:
        print(f"Epoch: {epoch} | Loss: {loss:.5f}, Accuracy: {acc:.2f}% | Test Loss: {test_loss:.5f}, Test Accuracy: {test_acc:.2f}%")
# Out:
# Epoch: 0 | Loss: 0.69358, Accuracy: 50.00% | Test Loss: 0.69362, Test Accuracy: 50.00%
# Epoch: 100 | Loss: 0.69191, Accuracy: 52.38% | Test Loss: 0.69162, Test Accuracy: 55.50%
# Epoch: 200 | Loss: 0.69070, Accuracy: 51.75% | Test Loss: 0.69010, Test Accuracy: 55.00%
# Epoch: 300 | Loss: 0.68918, Accuracy: 52.62% | Test Loss: 0.68816, Test Accuracy: 56.00%
# Epoch: 400 | Loss: 0.68718, Accuracy: 52.38% | Test Loss: 0.68558, Test Accuracy: 54.50%
# Epoch: 500 | Loss: 0.68466, Accuracy: 53.00% | Test Loss: 0.68230, Test Accuracy: 54.50%
# Epoch: 600 | Loss: 0.68175, Accuracy: 53.12% | Test Loss: 0.67847, Test Accuracy: 54.50%
# Epoch: 700 | Loss: 0.67851, Accuracy: 53.62% | Test Loss: 0.67435, Test Accuracy: 56.00%
# Epoch: 800 | Loss: 0.67501, Accuracy: 54.50% | Test Loss: 0.67002, Test Accuracy: 56.00%
# Epoch: 900 | Loss: 0.67089, Accuracy: 54.87% | Test Loss: 0.66516, Test Accuracy: 56.00%
# Epoch: 1000 | Loss: 0.66594, Accuracy: 55.62% | Test Loss: 0.65981, Test Accuracy: 57.50%
# Epoch: 1100 | Loss: 0.66053, Accuracy: 56.62% | Test Loss: 0.65469, Test Accuracy: 57.50%
# Epoch: 1200 | Loss: 0.65396, Accuracy: 58.25% | Test Loss: 0.64920, Test Accuracy: 60.50%
# Epoch: 1300 | Loss: 0.63979, Accuracy: 61.38% | Test Loss: 0.63899, Test Accuracy: 60.50%
# Epoch: 1400 | Loss: 0.62709, Accuracy: 62.88% | Test Loss: 0.62784, Test Accuracy: 61.00%
# Epoch: 1500 | Loss: 0.61376, Accuracy: 64.62% | Test Loss: 0.61554, Test Accuracy: 62.00%
# Epoch: 1600 | Loss: 0.59935, Accuracy: 66.62% | Test Loss: 0.60055, Test Accuracy: 64.00%
# Epoch: 1700 | Loss: 0.58522, Accuracy: 68.00% | Test Loss: 0.58509, Test Accuracy: 67.50%
# Epoch: 1800 | Loss: 0.57272, Accuracy: 68.25% | Test Loss: 0.57195, Test Accuracy: 68.50%
# Epoch: 1900 | Loss: 0.56167, Accuracy: 68.50% | Test Loss: 0.55995, Test Accuracy: 69.00%
# Epoch: 2000 | Loss: 0.55138, Accuracy: 69.12% | Test Loss: 0.54670, Test Accuracy: 69.00%
# Epoch: 2100 | Loss: 0.54162, Accuracy: 69.12% | Test Loss: 0.53451, Test Accuracy: 71.00%
# Epoch: 7700 | Loss: 0.46056, Accuracy: 70.88% | Test Loss: 0.43350, Test Accuracy: 74.00%
# Epoch: 7800 | Loss: 0.46036, Accuracy: 70.88% | Test Loss: 0.43338, Test Accuracy: 74.00%
# Epoch: 7900 | Loss: 0.46001, Accuracy: 70.88% | Test Loss: 0.43316, Test Accuracy: 74.00%
# Epoch: 8000 | Loss: 0.45977, Accuracy: 71.00% | Test Loss: 0.43326, Test Accuracy: 74.00%
# Epoch: 8100 | Loss: 0.45957, Accuracy: 71.00% | Test Loss: 0.43316, Test Accuracy: 74.00%
# Epoch: 8200 | Loss: 0.45932, Accuracy: 71.00% | Test Loss: 0.43311, Test Accuracy: 74.00%
# Epoch: 8300 | Loss: 0.45911, Accuracy: 71.00% | Test Loss: 0.43296, Test Accuracy: 74.00%
# Epoch: 8400 | Loss: 0.45891, Accuracy: 71.00% | Test Loss: 0.43283, Test Accuracy: 74.00%
# Epoch: 8500 | Loss: 0.45871, Accuracy: 71.00% | Test Loss: 0.43274, Test Accuracy: 74.00%
# Epoch: 8600 | Loss: 0.45851, Accuracy: 71.00% | Test Loss: 0.43254, Test Accuracy: 74.00%
# Epoch: 8700 | Loss: 0.45832, Accuracy: 71.00% | Test Loss: 0.43244, Test Accuracy: 74.00%
# Epoch: 8800 | Loss: 0.45814, Accuracy: 71.00% | Test Loss: 0.43235, Test Accuracy: 74.50%
# Epoch: 8900 | Loss: 0.45797, Accuracy: 71.00% | Test Loss: 0.43233, Test Accuracy: 74.50%
# Epoch: 9000 | Loss: 0.45780, Accuracy: 71.00% | Test Loss: 0.43227, Test Accuracy: 74.50%
# Epoch: 9100 | Loss: 0.45764, Accuracy: 71.00% | Test Loss: 0.43224, Test Accuracy: 74.50%
# Epoch: 9200 | Loss: 0.45749, Accuracy: 71.00% | Test Loss: 0.43219, Test Accuracy: 74.50%
# Epoch: 9300 | Loss: 0.45735, Accuracy: 71.00% | Test Loss: 0.43216, Test Accuracy: 74.50%
# Epoch: 9400 | Loss: 0.45720, Accuracy: 71.12% | Test Loss: 0.43207, Test Accuracy: 74.50%
# Epoch: 9500 | Loss: 0.45707, Accuracy: 71.12% | Test Loss: 0.43205, Test Accuracy: 74.50%
# Epoch: 9600 | Loss: 0.45693, Accuracy: 71.25% | Test Loss: 0.43203, Test Accuracy: 74.50%
# Epoch: 9700 | Loss: 0.45679, Accuracy: 71.25% | Test Loss: 0.43199, Test Accuracy: 74.50%
# Epoch: 9800 | Loss: 0.45665, Accuracy: 71.12% | Test Loss: 0.43187, Test Accuracy: 74.50%
# Epoch: 9900 | Loss: 0.45651, Accuracy: 71.00% | Test Loss: 0.43187, Test Accuracy: 74.50%

# %%
import requests
from pathlib import Path 

# Download helper functions from Learn PyTorch repo (if not already downloaded)
if Path("helper_functions.py").is_file():
  print("helper_functions.py already exists, skipping download")
else:
  print("Downloading helper_functions.py")
  request = requests.get("https://raw.githubusercontent.com/mrdbourke/pytorch-deep-learning/main/helper_functions.py")
  with open("helper_functions.py", "wb") as f:
    f.write(request.content)

from helper_functions import plot_predictions, plot_decision_boundary
# Out:
# helper_functions.py already exists, skipping download

# %%
# Make predictions
model_1.eval()
with torch.inference_mode():
    y_preds = torch.round(torch.sigmoid(model_1(X_test))).squeeze()
y_preds[:10], y[:10] # want preds in same format as truth labels
# Out:
# (tensor([1., 0., 1., 0., 1., 1., 0., 0., 1., 0.], device='cuda:0'),
#  tensor([1., 1., 1., 1., 0., 1., 1., 1., 1., 0.]))

# %%
from helper_functions import plot_decision_boundary
# Plot decision boundaries for training and test sets
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.title("Train")
plot_decision_boundary(model_1, X_train, y_train) # model_1 = no non-linearity
plt.subplot(1, 2, 2)
plt.title("Test")
plot_decision_boundary(model_1, X_test, y_test) # model_3 = has non-linearity
